# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pl_res = pd.read_csv('premier-league/results.csv')
pl_res.head(20)
# Out:
#             home_team          away_team  home_goals  away_goals result  \
# 0    Sheffield United          Liverpool         1.0         1.0      D
# 1             Arsenal        Aston Villa         1.0         1.0      D
# 2             Everton            Watford         2.0         1.0      H
# 3    Newcastle United     Wigan Athletic         2.0         1.0      H
# 4          Portsmouth   Blackburn Rovers         3.0         0.0      H
# 5             Reading      Middlesbrough         3.0         2.0      H
# 6     West Ham United  Charlton Athletic         3.0         1.0      H
# 7    Bolton Wanderers  Tottenham Hotspur         2.0         0.0      H
# 8   Manchester United             Fulham         5.0         1.0      H
# 9             Chelsea    Manchester City         3.0         0.0      H
# 10            Watford    West Ham United         1.0         1.0      D
# 11  Tottenham Hotspur   Sheffield United         2.0         0.0      H
# ...

# %%
pl_res.shape
# Out:
# (4560, 6)

# %%
pl_stats = pd.read_csv('premier-league/stats.csv')
pl_stats.shape
# Out:
# (240, 42)

# %%
pl_stats.head()
# Out:
#                 team  wins  losses  goals  total_yel_card  total_red_card  \
# 0  Manchester United  28.0     5.0   83.0            60.0             1.0
# 1            Chelsea  24.0     3.0   64.0            62.0             4.0
# 2          Liverpool  20.0    10.0   57.0            44.0             0.0
# 3            Arsenal  19.0     8.0   63.0            59.0             3.0
# 4  Tottenham Hotspur  17.0    12.0   57.0            48.0             3.0
#
#    total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  \
# 0              698.0                 256.0          21.0         12.0
# 1              636.0                 216.0          14.0         16.0
# 2              668.0                 214.0          15.0          8.0
# 3              638.0                 226.0          19.0         10.0
# 4              520.0                 184.0           6.0          5.0
#
#      ...      total_cross  corner_taken  touches  big_chance_missed  \
# ...

# %%
epd = pd.read_csv('english-premier-league-players-dataset-201718/epldata_final.csv')
epd.shape
# Out:
# (461, 17)

# %%
epd.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264     3.0           Chile
# 1        4395        9.5   5.60%         167     2.0         Germany
# 2        1529        5.5   5.90%         134     2.0  Czech Republic
# 3        2393        7.5   1.50%         122     1.0         England
# 4         912        6.0   0.70%         121     2.0          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
afa = pd.read_csv('africananalyst-english-premier-league-data-for-20-seasons-to-20172018/data/epl_20_yrs_data_1997_to_2018.csv')
afa.shape
# Out:
# (335160, 14)

# %%
afa.describe()
# Out:
#                 year       month_no          value
# count  335160.000000  335160.000000  335160.000000
# mean     2007.481203       6.737343       3.436147
# std         6.083845       3.906101       4.771100
# min      1997.000000       1.000000       0.000000
# 25%      2002.000000       3.000000       0.000000
# 50%      2007.000000       8.000000       1.000000
# 75%      2013.000000      10.000000       5.000000
# max      2018.000000      12.000000      43.000000

# %%
afa.head(100)
# Out:
#           date referee  year  month_no month_name       day date_for_season  \
# 0   1998-12-26     NaN  1998        12   December  Saturday      1998-12-26
# 1   1998-12-26     NaN  1998        12   December  Saturday      1998-12-26
# 2   1998-12-26     NaN  1998        12   December  Saturday      1998-12-26
# 3   1998-12-26     NaN  1998        12   December  Saturday      1998-12-26
# 4   1998-12-26     NaN  1998        12   December  Saturday      1998-12-26
# 5   1998-12-26     NaN  1998        12   December  Saturday      1998-12-26
# 6   1998-12-26     NaN  1998        12   December  Saturday      1998-12-26
# 7   1998-12-26     NaN  1998        12   December  Saturday      1998-12-26
# 8   1998-12-26     NaN  1998        12   December  Saturday      1998-12-26
# 9   1998-12-26     NaN  1998        12   December  Saturday      1998-12-26
# 10  1998-12-26     NaN  1998        12   December  Saturday      1998-12-26
# ...

# %%
afa_matchsummary = afa.groupby('key')
afa_matchsummary.head()
# Out:
#               date        referee  year  month_no month_name       day  \
# 0       1998-12-26            NaN  1998        12   December  Saturday
# 1       1998-12-26            NaN  1998        12   December  Saturday
# 2       1998-12-26            NaN  1998        12   December  Saturday
# 3       1998-12-26            NaN  1998        12   December  Saturday
# 4       1998-12-26            NaN  1998        12   December  Saturday
# 34      1998-12-26            NaN  1998        12   December  Saturday
# 35      1998-12-26            NaN  1998        12   December  Saturday
# 36      1998-12-26            NaN  1998        12   December  Saturday
# 37      1998-12-26            NaN  1998        12   December  Saturday
# 38      1998-12-26            NaN  1998        12   December  Saturday
# 62      1998-12-26            NaN  1998        12   December  Saturday
# 63      1998-12-26            NaN  1998        12   December  Saturday
# ...
